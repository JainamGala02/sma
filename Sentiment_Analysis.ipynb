# %%
import requests

# %%
video_id = "l-nMKJ5J3Uc"

api_key =  "AIzaSyCJF6Ljcay6oDQ1Bv-oO9ewD55Vktn_FEQ"

# %%
video_info_url = f"https://www.googleapis.com/youtube/v3/videos?part=snippet&id={video_id}&key={api_key}"
video_info_response = requests.get(video_info_url)
video_info_data = video_info_response.json()

print(video_info_data)
# Out:
# {'kind': 'youtube#videoListResponse', 'etag': 'aaQnEr8yg2fpHUPA7w5OL9p6Wxs', 'items': [{'kind': 'youtube#video', 'etag': '2n8pLX95tYMG-XYVSaAZdkMjTkY', 'id': 'l-nMKJ5J3Uc', 'snippet': {'publishedAt': '2024-04-20T15:59:59Z', 'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA', 'title': 'Ages 1 - 100 Decide Who Wins $250,000', 'description': 'I can’t believe who they picked\nThanks Top Troops for sponsoring this video. Download Top Troops at https://toptroops.onelink.me/JHnC/mrbeast or scan the QR code to get a FREE special Starter Pack for a limited time\n\nThanks Samsung for the Tab S9s - the Galaxy AI features are cool too: https://smsng.us/MrBTabS9\n\nNew Merch - https://mrbeast.store\n\nCheck out Viewstats! - https://www.viewstats.com/\n\nSUBSCRIBE OR I TAKE YOUR DOG\n╔═╦╗╔╦╗╔═╦═╦╦╦╦╗╔═╗\n║╚╣║║║╚╣╚╣╔╣╔╣║╚╣═╣ \n╠╗║╚╝║║╠╗║╚╣║║║║║═╣\n╚═╩══╩═╩═╩═╩╝╚╩═╩═╝\n\nFor any questions or inquiries regarding this video, please reach out to chucky@mrbeastbusiness.com\n\nAlso thank you Concept Pixel for the LED Walls,it looked great!\n\xa0www.conceptpixels.com\n\nMusic Provided by https://www.extrememusic.com\n\n----------------------------------------------------------------\nfollow all of these or i will kick you\n• Facebook - https://www.facebook.com/MrBeast6000/\n• Twitter - https://twitter.com/MrBeast\n•  Instagram - https://www.instagram.com/mrbeast\n•  Im Hiring! - https://www.mrbeastjobs.com/\n--------------------------------------------------------------------', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/l-nMKJ5J3Uc/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/l-nMKJ5J3Uc/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/l-nMKJ5J3Uc/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/l-nMKJ5J3Uc/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/l-nMKJ5J3Uc/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'channelTitle': 'MrBeast', 'categoryId': '24', 'liveBroadcastContent': 'none', 'defaultLanguage': 'en', 'localized': {'title': 'Ages 1 - 100 Decide Who Wins $250,000', 'description': 'I can’t believe who they picked\nThanks Top Troops for sponsoring this video. Download Top Troops at https://toptroops.onelink.me/JHnC/mrbeast or scan the QR code to get a FREE special Starter Pack for a limited time\n\nThanks Samsung for the Tab S9s - the Galaxy AI features are cool too: https://smsng.us/MrBTabS9\n\nNew Merch - https://mrbeast.store\n\nCheck out Viewstats! - https://www.viewstats.com/\n\nSUBSCRIBE OR I TAKE YOUR DOG\n╔═╦╗╔╦╗╔═╦═╦╦╦╦╗╔═╗\n║╚╣║║║╚╣╚╣╔╣╔╣║╚╣═╣ \n╠╗║╚╝║║╠╗║╚╣║║║║║═╣\n╚═╩══╩═╩═╩═╩╝╚╩═╩═╝\n\nFor any questions or inquiries regarding this video, please reach out to chucky@mrbeastbusiness.com\n\nAlso thank you Concept Pixel for the LED Walls,it looked great!\n\xa0www.conceptpixels.com\n\nMusic Provided by https://www.extrememusic.com\n\n----------------------------------------------------------------\nfollow all of these or i will kick you\n• Facebook - https://www.facebook.com/MrBeast6000/\n• Twitter - https://twitter.com/MrBeast\n•  Instagram - https://www.instagram.com/mrbeast\n•  Im Hiring! - https://www.mrbeastjobs.com/\n--------------------------------------------------------------------'}, 'defaultAudioLanguage': 'en'}}], 'pageInfo': {'totalResults': 1, 'resultsPerPage': 1}}

# %% [markdown]
# ***Retrieve Youtube Video Comments***

# %%
comments_url = f"https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId={video_id}&key={api_key}"
comments_response = requests.get(comments_url)
comments_data = comments_response.json()

comments_data
# Out:
# {'kind': 'youtube#commentThreadListResponse',
#  'etag': 'XKIX0XSaMlMBkvonLwF3AdLGuqc',
#  'nextPageToken': 'Z2V0X25ld2VzdF9maXJzdC0tQ2dnSWdBUVZGN2ZST0JJRkNLZ2dHQUFTQlFpZElCZ0JFZ1VJaVNBWUFCSUZDSWdnR0FBU0JRaUhJQmdBR0FBaURnb01DSkdTdjdFR0VMaWlqYThC',
#  'pageInfo': {'totalResults': 20, 'resultsPerPage': 20},
#  'items': [{'kind': 'youtube#commentThread',
#    'etag': 'bE0jizWZbGu3L5VT0S46VVZhqVM',
#    'id': 'UgwD2Uup_GluBePhdYF4AaABAg',
#    'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#     'videoId': 'l-nMKJ5J3Uc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'V9bX2ki9l7pF-tLjTDxVyqRkeKc',
#      'id': 'UgwD2Uup_GluBePhdYF4AaABAg',
#      'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#       'videoId': 'l-nMKJ5J3Uc',
#       'textDisplay': 'LONGER VIDEOS WITH STORYTELLING IS HERE',
#       'textOriginal': 'LONGER VIDEOS WITH STORYTELLING IS HERE',
#       'authorDisplayName': '@MrBeast',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/fxGKYucJAVme-Yz4fsdCroCFCrANWqw0ql4GYuvx8Uq4l_euNJHgE-w9MTkLQA805vWCi-kE0g=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@MrBeast',
#       'authorChannelId': {'value': 'UCX6OQ3DkcsbYNE6H8uQQuVA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 207250,
#       'publishedAt': '2024-04-20T17:00:36Z',
#       'updatedAt': '2024-04-20T17:00:36Z'}},
#     'canReply': False,
#     'totalReplyCount': 750,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'X-jV7KzhuSUfxr7tCYdTVTGTetA',
#    'id': 'UgwXn0ACQDrRrystJ9R4AaABAg',
#    'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#     'videoId': 'l-nMKJ5J3Uc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'Tp5GPAHVQmZEbcK_42W0UWxUFIc',
#      'id': 'UgwXn0ACQDrRrystJ9R4AaABAg',
#      'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#       'videoId': 'l-nMKJ5J3Uc',
#       'textDisplay': 'Ótimo ver a eliminação do 42. Gente arrogante como ele não merece',
#       'textOriginal': 'Ótimo ver a eliminação do 42. Gente arrogante como ele não merece',
#       'authorDisplayName': '@TheLekizika',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lmep3QzuACpeTq_FeIZt4iCfEbg-sMc9PnKcJp8-va374=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@TheLekizika',
#       'authorChannelId': {'value': 'UCR7BQ6Y9huHceFjAgbcjqmg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-04-29T16:37:45Z',
#       'updatedAt': '2024-04-29T16:37:45Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'IrpOcXk-M1i7eUHwJzeUXJ1O01M',
#    'id': 'UgxQFyM7gPB2IxEzoe94AaABAg',
#    'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#     'videoId': 'l-nMKJ5J3Uc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'NdLY4cLSDMApiW4Nj02eo9SK93o',
#      'id': 'UgxQFyM7gPB2IxEzoe94AaABAg',
#      'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#       'videoId': 'l-nMKJ5J3Uc',
#       'textDisplay': 'El 42 me cae mal',
#       'textOriginal': 'El 42 me cae mal',
#       'authorDisplayName': '@Marco15parra',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/XLhIvGMEqknH9aNjAXdcbriEql2s5slZstWGhVWgGSCktK64SFvC7dM9upvJKuj05UcObgWWPjc=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@Marco15parra',
#       'authorChannelId': {'value': 'UC_D1MAI21Ts0xEIbMULqWhA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-04-29T16:37:15Z',
#       'updatedAt': '2024-04-29T16:37:15Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'XDV78xhNXU3JOF8vdoNh0Vqsn5A',
#    'id': 'UgyKaXTiDwvHYZYIAHh4AaABAg',
#    'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#     'videoId': 'l-nMKJ5J3Uc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '6lOI0vFMy6uCZP8TmSwqmXwxv5A',
#      'id': 'UgyKaXTiDwvHYZYIAHh4AaABAg',
#      'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#       'videoId': 'l-nMKJ5J3Uc',
#       'textDisplay': 'Cómo llore en la este video😢',
#       'textOriginal': 'Cómo llore en la este video😢',
#       'authorDisplayName': '@angelicagomez9704',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_l1_xUW8vCER5aZOENYiuYSGDxi_Ekg3KYyPtPWw-4h-A=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@angelicagomez9704',
#       'authorChannelId': {'value': 'UCXazHjS490d1Z4PsHQobgZw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-04-29T16:37:03Z',
#       'updatedAt': '2024-04-29T16:37:03Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'PLJIWBBkmN2ZPJlT3tviHfx4OMM',
#    'id': 'UgwpsYFWXZBERrP7W614AaABAg',
#    'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#     'videoId': 'l-nMKJ5J3Uc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '0WKPiue4s9wVL2XWTsXCu4Eruf8',
#      'id': 'UgwpsYFWXZBERrP7W614AaABAg',
#      'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#       'videoId': 'l-nMKJ5J3Uc',
#       'textDisplay': 'awesome video',
#       'textOriginal': 'awesome video',
#       'authorDisplayName': '@psychoticold',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_klVSaD73JNdIZ-4D9Vq9v44-Op6vI3MyILJPidVDNuF6Txt3clSU2Y4LykBuPH4SF9Fg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@psychoticold',
#       'authorChannelId': {'value': 'UCjsRn-dEoCxPa4LZ6CioX3A'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-04-29T16:36:41Z',
#       'updatedAt': '2024-04-29T16:36:41Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '-QbVBzKsrBIE-470f_U_TOYXl8Y',
#    'id': 'Ugw6hJqOrEZiiWGYnC54AaABAg',
#    'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#     'videoId': 'l-nMKJ5J3Uc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '_3mI2SwEUMu-n68hRxkBrW2c1qQ',
#      'id': 'Ugw6hJqOrEZiiWGYnC54AaABAg',
#      'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#       'videoId': 'l-nMKJ5J3Uc',
#       'textDisplay': '47 You are the most cruel person.',
#       'textOriginal': '47 You are the most cruel person.',
#       'authorDisplayName': '@user-xf6fm6js1e',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_n9rKtg67PI84YUMfZ1hfUq_3fSKvNhI2nccBroaeKpim_jgPgLfiRmQtPGJ9_Qby6gTrA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@user-xf6fm6js1e',
#       'authorChannelId': {'value': 'UCUcdvrUVlifJQjaZL8CyQiA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-04-29T16:35:54Z',
#       'updatedAt': '2024-04-29T16:35:54Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '5kMGm5lOvMRkVjzxBMaYUzk4oX4',
#    'id': 'UgxIS0YpC9ueq01-gO94AaABAg',
#    'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#     'videoId': 'l-nMKJ5J3Uc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '_6FNOI2ysiwc_SomokOs2YbMSxk',
#      'id': 'UgxIS0YpC9ueq01-gO94AaABAg',
#      'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#       'videoId': 'l-nMKJ5J3Uc',
#       'textDisplay': '42😈😈😈',
#       'textOriginal': '42😈😈😈',
#       'authorDisplayName': '@user-xh6xj7xw3z',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/bKHV3Hz_zI5pbYPpIY6-Zj9bxevfgWGPAVJDFwRjtwYCLGxXSF_Qk0dwgxILKoBs5Mn_ViFX=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@user-xh6xj7xw3z',
#       'authorChannelId': {'value': 'UC1PqGmqpxdIz0awy3unRV5g'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-04-29T16:34:28Z',
#       'updatedAt': '2024-04-29T16:34:28Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'ZETFKARDkRZkPL0o9EGfJOErAUs',
#    'id': 'UgypJynGLQIjV1fWmjF4AaABAg',
#    'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#     'videoId': 'l-nMKJ5J3Uc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'ma0eAkW7fo1WcvdEdLGLriHncg8',
#      'id': 'UgypJynGLQIjV1fWmjF4AaABAg',
#      'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#       'videoId': 'l-nMKJ5J3Uc',
#       'textDisplay': 'They did him dirty😭 <a href="https://www.youtube.com/watch?v=l-nMKJ5J3Uc&amp;t=234">3:54</a>',
#       'textOriginal': 'They did him dirty😭 3:54',
#       'authorDisplayName': '@Squidwardor',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/aodd0ULDieskbN8f2XSl3DSVTdjmjl997Yf1I2cc9QOFfVLS8t4qlWGM8ps5Swau2FPv8VxJKA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@Squidwardor',
#       'authorChannelId': {'value': 'UCeJkrKzYiQmAmLBl7AGzK2Q'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-04-29T16:34:17Z',
#       'updatedAt': '2024-04-29T16:34:26Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'UGoI3wPjFnMzKdsNHQNKnr5-tZc',
#    'id': 'UgwiL1WCns96r22Hj8J4AaABAg',
#    'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#     'videoId': 'l-nMKJ5J3Uc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'VacE1Ibe9MX7ozjx9lGv6vbxf0w',
#      'id': 'UgwiL1WCns96r22Hj8J4AaABAg',
#      'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#       'videoId': 'l-nMKJ5J3Uc',
#       'textDisplay': 'I would pay to watch 42 complete in another mrbeast video',
#       'textOriginal': 'I would pay to watch 42 complete in another mrbeast video',
#       'authorDisplayName': '@mr.parashar',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/-WmLE_MaVmgN0Nj2hVP3e42xk4DIWHwB-o0Rz-7HkYPFkzamaAaL-EzdMdY8o_p5yHJiKUn3oaE=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@mr.parashar',
#       'authorChannelId': {'value': 'UC8oxIdRzU4Z6P5UFy7FOwfA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-04-29T16:34:11Z',
#       'updatedAt': '2024-04-29T16:34:11Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'IKBecCETWYaWeKfB3YaurOmElWc',
#    'id': 'UgwqC1rfsbSvvXmGEEB4AaABAg',
#    'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#     'videoId': 'l-nMKJ5J3Uc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '6-JdgO1kGAGoFwnl57HiiGWH1xQ',
#      'id': 'UgwqC1rfsbSvvXmGEEB4AaABAg',
#      'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#       'videoId': 'l-nMKJ5J3Uc',
#       'textDisplay': '42 deserved the money, he made the entire video entertaining',
#       'textOriginal': '42 deserved the money, he made the entire video entertaining',
#       'authorDisplayName': '@RandomVideos-yz5qf',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_kgbmkUL1uKX3uL67Y-KZXdR35OKsb24bUrlrDk2LM=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@RandomVideos-yz5qf',
#       'authorChannelId': {'value': 'UCiRK_NLQ0okBjJWQYx4C7dQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-04-29T16:32:30Z',
#       'updatedAt': '2024-04-29T16:32:30Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'LoWHMriZph6BWmxDHjeS2uhNf6Y',
#    'id': 'UgxeZ6NkFMapuPnYq814AaABAg',
#    'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#     'videoId': 'l-nMKJ5J3Uc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'I-O5Yn6ODCknk7PG0-djJxvv-L0',
#      'id': 'UgxeZ6NkFMapuPnYq814AaABAg',
#      'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#       'videoId': 'l-nMKJ5J3Uc',
#       'textDisplay': 'Honestly I love 42',
#       'textOriginal': 'Honestly I love 42',
#       'authorDisplayName': '@SantsunTheDemon',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/jSRzJVklWd886G1f-hRg30sQ1s8MvYYmnQRA8dKxqRVsSZD33UI_ZZehmW3RYJzJG0R5pJCa-Q=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@SantsunTheDemon',
#       'authorChannelId': {'value': 'UCfMXNWcqmGRHFAaWjsYtiCQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-04-29T16:31:46Z',
#       'updatedAt': '2024-04-29T16:31:46Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'rkpDyac5aHPQFfSIgb69jEtLEy0',
#    'id': 'Ugw_ZtO09ycSJeGRYu54AaABAg',
#    'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#     'videoId': 'l-nMKJ5J3Uc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'dEGJ6PuQr8hbFPhPxYf4VmuPNNE',
#      'id': 'Ugw_ZtO09ycSJeGRYu54AaABAg',
#      'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#       'videoId': 'l-nMKJ5J3Uc',
#       'textDisplay': '42 is Manipulateing 43',
#       'textOriginal': '42 is Manipulateing 43',
#       'authorDisplayName': '@jasonslayer4324',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/9va8jzvt6pD4jsIe6g4pu9Kl-f6gEY25JGAMi3ATMBTX52qpnHoGB70ei8D2vd1bYvlotxmBdw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@jasonslayer4324',
#       'authorChannelId': {'value': 'UCbRFCf2ER9Q5wQgPXJWBaxw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-04-29T16:30:34Z',
#       'updatedAt': '2024-04-29T16:30:34Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '_Q5byVlCp3eoFf38z4urZkWzCcI',
#    'id': 'UgwxPotV6Ye6BqFdaQt4AaABAg',
#    'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#     'videoId': 'l-nMKJ5J3Uc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '8DYXVgrnZ5XcGE31jE4ZEAUE9js',
#      'id': 'UgwxPotV6Ye6BqFdaQt4AaABAg',
#      'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#       'videoId': 'l-nMKJ5J3Uc',
#       'textDisplay': 'this video make me cry😢',
#       'textOriginal': 'this video make me cry😢',
#       'authorDisplayName': '@-_-Ender-_-816',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/o5yJ2npL0TiRnfwBSmPbsD3Q16kIeIOUhvYzSlove1wsDCpulh4aZmE9wFR5OoWjnJT-u_njQw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@-_-Ender-_-816',
#       'authorChannelId': {'value': 'UCBdKRam_1_SI4GrV7SAsCkQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-04-29T16:28:06Z',
#       'updatedAt': '2024-04-29T16:28:06Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'CCrYPFAN7RnVShHEZUacJdXxYGc',
#    'id': 'UgyIb4t3AHozsor9pSF4AaABAg',
#    'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#     'videoId': 'l-nMKJ5J3Uc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'I8eq3STHoJr42Quo0X1hYPIAwlA',
#      'id': 'UgyIb4t3AHozsor9pSF4AaABAg',
#      'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#       'videoId': 'l-nMKJ5J3Uc',
#       'textDisplay': 'Why are you so ruthless, why insulting old people ?',
#       'textOriginal': 'Why are you so ruthless, why insulting old people ?',
#       'authorDisplayName': '@mudrajshihjadeja3465',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_k2bYehRuCRAn3zSVISAs8zWfdXbb_LEELNTAgf0S0=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@mudrajshihjadeja3465',
#       'authorChannelId': {'value': 'UCS5D5b40SvQd8ac7ljJEqKw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2024-04-29T16:27:48Z',
#       'updatedAt': '2024-04-29T16:27:48Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'bCvgZUsAzMNlBeImUYXSKXm9KyA',
#    'id': 'UgzCKKWO_pGe_pHtHht4AaABAg',
#    'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#     'videoId': 'l-nMKJ5J3Uc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'BtEb5DN23XRv0kmGCbF6SpX6JOs',
#      'id': 'UgzCKKWO_pGe_pHtHht4AaABAg',
#      'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#       'videoId': 'l-nMKJ5J3Uc',
#       'textDisplay': '42 is actually a villain the voice in 43’s head',
#       'textOriginal': '42 is actually a villain the voice in 43’s head',
#       'authorDisplayName': '@apricot662',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/2hAnurchXELLmgxVADKSaakQxCE31hxreq2dLCJfOyR7pqfMZioJMzELXutewM1KMnRRbtXQqX4=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@apricot662',
#       'authorChannelId': {'value': 'UCpFxDY6RUEgs7A6r42z--5A'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-04-29T16:26:32Z',
#       'updatedAt': '2024-04-29T16:28:30Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'nwqAvzVq8i2MmM8wCipN2K2v_28',
#    'id': 'Ugxy7WTs7cbdsn6-j-N4AaABAg',
#    'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#     'videoId': 'l-nMKJ5J3Uc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'vPVWQ_b1W2TL9he2Qtnfy_b6Daw',
#      'id': 'Ugxy7WTs7cbdsn6-j-N4AaABAg',
#      'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#       'videoId': 'l-nMKJ5J3Uc',
#       'textDisplay': 'Bro really said Womp Womp',
#       'textOriginal': 'Bro really said Womp Womp',
#       'authorDisplayName': '@hectortansari3826',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/QS5lu7AUf9QPXyAOEiuTql8o1dowT9VCssDPDmom3r0XxnNMM9-by3srueeoe6Dx018YVkkhDQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@hectortansari3826',
#       'authorChannelId': {'value': 'UC-dk5-0eWKZQ-K1vimtthSw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-04-29T16:26:24Z',
#       'updatedAt': '2024-04-29T16:26:24Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'MnpOhu3b6aqs39ul3JYu33H6ZvQ',
#    'id': 'Ugxogqau3fW69o4X6Nx4AaABAg',
#    'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#     'videoId': 'l-nMKJ5J3Uc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'dTzgLLMfzb04z6ZhKh_gH-J6j5E',
#      'id': 'Ugxogqau3fW69o4X6Nx4AaABAg',
#      'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#       'videoId': 'l-nMKJ5J3Uc',
#       'textDisplay': '48',
#       'textOriginal': '48',
#       'authorDisplayName': '@pialopez6088',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_n1V0bvgH7YALJeOc2xITFqptOlmIih0sSzPTZdnkLnYw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@pialopez6088',
#       'authorChannelId': {'value': 'UCpZbnZd55XhWVgs3Qjm1ciQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2024-04-29T16:24:10Z',
#       'updatedAt': '2024-04-29T16:24:10Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'lNDvzO3McU1aKVwV8e--9YH4cg0',
#    'id': 'UgzdSugfEOszP8qOSSh4AaABAg',
#    'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#     'videoId': 'l-nMKJ5J3Uc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '2yH7XZEwkAH5CDSL6ErWm2mAdGY',
#      'id': 'UgzdSugfEOszP8qOSSh4AaABAg',
#      'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#       'videoId': 'l-nMKJ5J3Uc',
#       'textDisplay': 'Increíble muy bonito 🎉😊 desde España os queremos 😊',
#       'textOriginal': 'Increíble muy bonito 🎉😊 desde España os queremos 😊',
#       'authorDisplayName': '@Ivan-gz5oz',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/gfXdTfOi0wfsBSH_ONzP1RxbYjeYDvKC5lAFq7rJ1W6ZVtyoLKPC2mI-L-21Zfy3k57zoPmQ8g=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@Ivan-gz5oz',
#       'authorChannelId': {'value': 'UCLDWn3wAtzzi6ZvlkTwhE3A'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-04-29T16:22:38Z',
#       'updatedAt': '2024-04-29T16:22:38Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'G3zbllQsWwTVVZZRG6J9eYowRGk',
#    'id': 'UgzufDYxZvoD77KSMP14AaABAg',
#    'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#     'videoId': 'l-nMKJ5J3Uc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'Uszh6ownem5BIdPY4Gkc1aGK5cY',
#      'id': 'UgzufDYxZvoD77KSMP14AaABAg',
#      'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#       'videoId': 'l-nMKJ5J3Uc',
#       'textDisplay': 'El español secunsario es la voz de fede vigevani',
#       'textOriginal': 'El español secunsario es la voz de fede vigevani',
#       'authorDisplayName': '@Helpfpsx_xio',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/S2b-x_IfDeUTdiUj7EQb1X-8S9QjSLnvLJ0UWNOaKKhYeA0MyGX15xhCHN0PNGl4n9n-gLPR-Q0=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@Helpfpsx_xio',
#       'authorChannelId': {'value': 'UChqrNxxxJU0EWg614GJuEhQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-04-29T16:21:53Z',
#       'updatedAt': '2024-04-29T16:21:53Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'gC827NyAP_z1jMfVGUv79RO8r_4',
#    'id': 'Ugx9SUwr1A7PXBdGE9h4AaABAg',
#    'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#     'videoId': 'l-nMKJ5J3Uc',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'GPDtszhaVWHNVqK0DzZPKa8WjII',
#      'id': 'Ugx9SUwr1A7PXBdGE9h4AaABAg',
#      'snippet': {'channelId': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#       'videoId': 'l-nMKJ5J3Uc',
#       'textDisplay': '42 is a evil guy.',
#       'textOriginal': '42 is a evil guy.',
#       'authorDisplayName': '@user-mu7wm8pb1g',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mglSGNWk20-HpB6wp4hDTlkjSknX7Mob79E28e-oGndr22p_2wSbntTBphlxeuIcZhlA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@user-mu7wm8pb1g',
#       'authorChannelId': {'value': 'UCwkKR2KhpD06adueAFtMZsg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2024-04-29T16:21:38Z',
#       'updatedAt': '2024-04-29T16:21:38Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}}]}

# %%
#extract the comment

comments = [item["snippet"]["topLevelComment"]["snippet"]["textOriginal"] for item in comments_data["items"]]

print(comments)
# Out:
# ['LONGER VIDEOS WITH STORYTELLING IS HERE', 'Ótimo ver a eliminação do 42. Gente arrogante como ele não merece', 'El 42 me cae mal', 'Cómo llore en la este video😢', 'awesome video', '47 You are the most cruel person.', '42😈😈😈', 'They did him dirty😭 3:54', 'I would pay to watch 42 complete in another mrbeast video', '42 deserved the money, he made the entire video entertaining', 'Honestly I love 42', '42 is Manipulateing 43', 'this video make me cry😢', 'Why are you so ruthless, why insulting old people ?', '42 is actually a villain the voice in 43’s head', 'Bro really said Womp Womp', '48', 'Increíble muy bonito 🎉😊 desde España os queremos 😊', 'El español secunsario es la voz de fede vigevani', '42 is a evil guy.']

# %% [markdown]
# ***Sentiments Analysis Of the Comments***

# %%
from textblob import TextBlob

# %%
def get_comment_sentiment(comment):
    analysis = TextBlob(comment)

    if analysis.sentiment.polarity > 0:
        return 'positive'
    elif analysis.sentiment.polarity == 0:
        return 'neutral'
    else:
        return 'nagative'

for comment in comments:
    print(f"{comment}: {get_comment_sentiment(comment)}")

comment_list = []

sentiment_list =[]

for comment in comments:
    sentiment = get_comment_sentiment(comment)
    comment_list.append(comment)
    sentiment_list.append(sentiment)
    print(f"{comment} : {sentiment}")
# Out:
# LONGER VIDEOS WITH STORYTELLING IS HERE: neutral
# Ótimo ver a eliminação do 42. Gente arrogante como ele não merece: neutral
# El 42 me cae mal: neutral
# Cómo llore en la este video😢: neutral
# awesome video: positive
# 47 You are the most cruel person.: nagative
# 42😈😈😈: neutral
# They did him dirty😭 3:54: neutral
# I would pay to watch 42 complete in another mrbeast video: positive
# 42 deserved the money, he made the entire video entertaining: positive
# Honestly I love 42: positive
# 42 is Manipulateing 43: neutral
# this video make me cry😢: neutral
# Why are you so ruthless, why insulting old people ?: nagative
# 42 is actually a villain the voice in 43’s head: neutral
# Bro really said Womp Womp: positive
# 48: neutral
# Increíble muy bonito 🎉😊 desde España os queremos 😊: neutral
# El español secunsario es la voz de fede vigevani: neutral
# 42 is a evil guy.: nagative
# LONGER VIDEOS WITH STORYTELLING IS HERE : neutral
# Ótimo ver a eliminação do 42. Gente arrogante como ele não merece : neutral
# El 42 me cae mal : neutral
# Cómo llore en la este video😢 : neutral
# awesome video : positive
# 47 You are the most cruel person. : nagative
# 42😈😈😈 : neutral
# They did him dirty😭 3:54 : neutral
# I would pay to watch 42 complete in another mrbeast video : positive
# 42 deserved the money, he made the entire video entertaining : positive
# Honestly I love 42 : positive
# 42 is Manipulateing 43 : neutral
# this video make me cry😢 : neutral
# Why are you so ruthless, why insulting old people ? : nagative
# 42 is actually a villain the voice in 43’s head : neutral
# Bro really said Womp Womp : positive
# 48 : neutral
# Increíble muy bonito 🎉😊 desde España os queremos 😊 : neutral
# El español secunsario es la voz de fede vigevani : neutral
# 42 is a evil guy. : nagative

# %%
import pandas as pd

comment_list

sentiment_list

sentiment_df = pd.DataFrame({"Comments": comment_list,"Sentiment": sentiment_list})

sentiment_df

sentiment_df.to_csv("YouTube_Comments_Sentiment.csv")  #gets saved to current folder

# %%
comments
# Out:
# ['LONGER VIDEOS WITH STORYTELLING IS HERE',
#  'Ótimo ver a eliminação do 42. Gente arrogante como ele não merece',
#  'El 42 me cae mal',
#  'Cómo llore en la este video😢',
#  'awesome video',
#  '47 You are the most cruel person.',
#  '42😈😈😈',
#  'They did him dirty😭 3:54',
#  'I would pay to watch 42 complete in another mrbeast video',
#  '42 deserved the money, he made the entire video entertaining',
#  'Honestly I love 42',
#  '42 is Manipulateing 43',
#  'this video make me cry😢',
#  'Why are you so ruthless, why insulting old people ?',
#  '42 is actually a villain the voice in 43’s head',
#  'Bro really said Womp Womp',
#  '48',
#  'Increíble muy bonito 🎉😊 desde España os queremos 😊',
#  'El español secunsario es la voz de fede vigevani',
#  '42 is a evil guy.']

# %%
sentiment_df
# Out:
#                                              Comments Sentiment
# 0             LONGER VIDEOS WITH STORYTELLING IS HERE   neutral
# 1   7 said  I will buy you Roblox I promise if you...   neutral
# 2                        Wish I was in a mr beast vid   neutral
# 3                               Best video in a while  positive
# 4   42 was a literal puppeteer, just absolutely co...  positive
# 5                      40s are evil mostly 43 and 42.  nagative
# 6              Longer vids are always better brother.  positive
# 7                 I’m fighting who ever eliminates me   neutral
# 8   Mrbeast slowly turning his channel into squid ...  nagative
# 9                                Me cae mal 43 and 42   neutral
# 10          "Now is not the time to develop a heart"🥶   neutral
# 11                                            ❤❤❤❤🎉🎉🎉   neutral
# 12                           96years old is amazing 😮  positive
# 13                  42 is such a cartoon Villain 😂😂😂😂   neutral
# 14                         i cried because of the 40s   neutral
# 15  I didn't even notice that this video was 40 mi...  positive
# 16                 Esse foi o vídeo que eu mais odiei   neutral
# 17                       dis is psychological torture   neutral
# 18  Hey what I want you to do is go to time stamp ...   neutral
# 19              good job no that I was sad in the end  positive
